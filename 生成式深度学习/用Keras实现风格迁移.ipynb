# %% [markdown]
# # 用Keras实现风格迁移
# ## 一、导入所需库

# %%
from tensorflow import keras
import tensorflow.compat.v2.keras.backend as K
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.applications import vgg19
import tensorflow as tf
# tf.compat.v1.disable_eager_execution()

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.compat.v1 import ConfigProto, Session
config = ConfigProto(allow_soft_placement=True)

config.gpu_options.per_process_gpu_memory_fraction = 0.6
set_session(Session(config=config))

# %% [markdown]
# ## 查看VGG19的模型

# %%
conv_base = vgg19.VGG19(include_top=False)
conv_base.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 定义初始变量

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
target_image_path = '/home/oneran/temp.JPEG'    #需要变换的路径
style_referrence_image_path = '/home/oneran/Downloads/referrence_style.jpg'

width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)

# %% [markdown]
# ## 引入辅助函数

# %%
def preprocessing_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)           
    return img

def deprocess_img(x):
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %% [markdown]
# ## 加载预训练的VGG19网络，并且将其引用与三张图像

# %%
tf.compat.v1.disable_eager_execution()

# %%
target_img = K.constant(preprocessing_image(target_image_path))
style_referrence_image = K.constant(preprocessing_image(style_referrence_image_path))
combination_image = K.placeholder((1, img_height, img_width, 3))

input_tensor = K.concatenate([target_img, style_referrence_image, combination_image], axis=0) # 将三张图片连接起来  拼接在第四个轴上

model = vgg19.VGG19(input_tensor=input_tensor, weights='imagenet', include_top=False)
print('Model loaded!')
# Out:
# Model loaded!

# %% [markdown]
# ## 定义内容损失和风格损失

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination-base))   #均方和作为内容损失

def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))   #风格损失为矩阵内积
    return gram

def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S-C)) / (4. * (channels ** 2) * (size ** 2))

# %% [markdown]
# ## 总变差损失

# %%
def total_variation_loss(x):
    a = K.square(
        x[:, :img_height-1, :img_width-1, :] - x[:, 1:, img_width-1:, :]            #去掉边缘影响
    )
    b = K.square(
        x[:, :img_height-1, :img_width-1, :] - x[:, img_height-1, 1, :]
    )
    return K.sum(K.pow(a+b, 1.25))

# %% [markdown]
# ## 定义最终损失

# %%
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
content_layer = 'block5_conv2'
style_layer = [ 'block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']
total_variation_weight = 1e-4
style_weight = 1.
content_weight = 0.025

loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(target_image_features, combination_features)

for layer_name in style_layer:
    layer_features = outputs_dict[layer_name]
    style_referrence_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    s1 = style_loss(style_referrence_features, combination_features)
    loss += (style_weight / len(style_layer)) * s1

loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %% [markdown]
# ## 设置梯度下降过程

# %%
grads = K.gradients(loss, combination_image)[0]
fetch_loss_and_grads = K.function([combination_image], [loss, grads])

class Evaluator(object):
    def __init__(self):
        self.loss_value = None
        self.grads_value = None

    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grads_value = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grads_value = grads_value
        return self.loss_value
    
    def grads(self, x):
        assert self.loss_value is not None
        grads_value = np.copy(self.grads_value)
        self.loss_value = None
        self.grads_value = None
        return grads_value

evaluator = Evaluator()

# %% [markdown]
# ## 风格迁移循环

# %%
from scipy.optimize import fmin_l_bfgs_b
from matplotlib.pyplot import imsave
import time

result_prefix = '/home/oneran/testimages/my_results_'
iterations = 100

x = preprocessing_image(target_image_path)
x = x.flatten()
for i in range(iterations):
    print('Start of iterations:', i)
    start_Time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x, fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_img(img)
    fname = result_prefix + 'at_iteration_%d_img.jpg' %i
    imsave(fname, img)
    print('Image saved as', fname)
    end_time = time.time()
    print('Iterations %d completed in %ds' %(i, end_time-start_Time))
# Out:
# Start of iterations: 0
# Current loss value: 3219840000.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_0_img.jpg
# Iterations 0 completed in 19s
# Start of iterations: 1
# Current loss value: 1528704000.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_1_img.jpg
# Iterations 1 completed in 11s
# Start of iterations: 2
# Current loss value: 1045426240.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_2_img.jpg
# Iterations 2 completed in 11s
# Start of iterations: 3
# Current loss value: 823283140.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_3_img.jpg
# Iterations 3 completed in 11s
# Start of iterations: 4
# Current loss value: 668472800.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_4_img.jpg
# Iterations 4 completed in 11s
# Start of iterations: 5
# Current loss value: 580536960.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_5_img.jpg
# Iterations 5 completed in 11s
# Start of iterations: 6
# Current loss value: 510830100.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_6_img.jpg
# Iterations 6 completed in 11s
# Start of iterations: 7
# Current loss value: 459736400.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_7_img.jpg
# Iterations 7 completed in 11s
# Start of iterations: 8
# Current loss value: 419197900.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_8_img.jpg
# Iterations 8 completed in 10s
# Start of iterations: 9
# Current loss value: 387605380.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_9_img.jpg
# Iterations 9 completed in 10s
# Start of iterations: 10
# Current loss value: 360020960.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_10_img.jpg
# Iterations 10 completed in 10s
# Start of iterations: 11
# Current loss value: 338411040.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_11_img.jpg
# Iterations 11 completed in 10s
# Start of iterations: 12
# Current loss value: 319330780.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_12_img.jpg
# Iterations 12 completed in 11s
# Start of iterations: 13
# Current loss value: 301228700.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_13_img.jpg
# Iterations 13 completed in 10s
# Start of iterations: 14
# Current loss value: 285295550.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_14_img.jpg
# Iterations 14 completed in 10s
# Start of iterations: 15
# Current loss value: 271411100.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_15_img.jpg
# Iterations 15 completed in 10s
# Start of iterations: 16
# Current loss value: 256622980.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_16_img.jpg
# Iterations 16 completed in 10s
# Start of iterations: 17
# Current loss value: 242388110.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_17_img.jpg
# Iterations 17 completed in 10s
# Start of iterations: 18
# Current loss value: 229686960.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_18_img.jpg
# Iterations 18 completed in 10s
# Start of iterations: 19
# Current loss value: 220391580.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_19_img.jpg
# Iterations 19 completed in 12s
# Start of iterations: 20
# Current loss value: 212405120.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_20_img.jpg
# Iterations 20 completed in 10s
# Start of iterations: 21
# Current loss value: 205000860.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_21_img.jpg
# Iterations 21 completed in 11s
# Start of iterations: 22
# Current loss value: 197525070.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_22_img.jpg
# Iterations 22 completed in 12s
# Start of iterations: 23
# Current loss value: 191456960.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_23_img.jpg
# Iterations 23 completed in 12s
# Start of iterations: 24
# Current loss value: 185284530.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_24_img.jpg
# Iterations 24 completed in 13s
# Start of iterations: 25
# Current loss value: 179094100.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_25_img.jpg
# Iterations 25 completed in 11s
# Start of iterations: 26
# Current loss value: 174228380.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_26_img.jpg
# Iterations 26 completed in 12s
# Start of iterations: 27
# Current loss value: 169696660.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_27_img.jpg
# Iterations 27 completed in 12s
# Start of iterations: 28
# Current loss value: 165732700.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_28_img.jpg
# Iterations 28 completed in 12s
# Start of iterations: 29
# Current loss value: 161843710.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_29_img.jpg
# Iterations 29 completed in 12s
# Start of iterations: 30
# Current loss value: 158571230.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_30_img.jpg
# Iterations 30 completed in 12s
# Start of iterations: 31
# Current loss value: 154202380.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_31_img.jpg
# Iterations 31 completed in 13s
# Start of iterations: 32
# Current loss value: 150444000.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_32_img.jpg
# Iterations 32 completed in 11s
# Start of iterations: 33
# Current loss value: 147541650.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_33_img.jpg
# Iterations 33 completed in 11s
# Start of iterations: 34
# Current loss value: 144918260.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_34_img.jpg
# Iterations 34 completed in 12s
# Start of iterations: 35
# Current loss value: 141237150.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_35_img.jpg
# Iterations 35 completed in 12s
# Start of iterations: 36
# Current loss value: 138352640.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_36_img.jpg
# Iterations 36 completed in 11s
# Start of iterations: 37
# Current loss value: 135288750.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_37_img.jpg
# Iterations 37 completed in 12s
# Start of iterations: 38
# Current loss value: 132710270.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_38_img.jpg
# Iterations 38 completed in 12s
# Start of iterations: 39
# Current loss value: 130207560.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_39_img.jpg
# Iterations 39 completed in 12s
# Start of iterations: 40
# Current loss value: 128084790.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_40_img.jpg
# Iterations 40 completed in 12s
# Start of iterations: 41
# Current loss value: 125780200.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_41_img.jpg
# Iterations 41 completed in 11s
# Start of iterations: 42
# Current loss value: 123646950.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_42_img.jpg
# Iterations 42 completed in 11s
# Start of iterations: 43
# Current loss value: 121894820.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_43_img.jpg
# Iterations 43 completed in 12s
# Start of iterations: 44
# Current loss value: 120068450.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_44_img.jpg
# Iterations 44 completed in 12s
# Start of iterations: 45
# Current loss value: 118330200.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_45_img.jpg
# Iterations 45 completed in 12s
# Start of iterations: 46
# Current loss value: 116619750.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_46_img.jpg
# Iterations 46 completed in 12s
# Start of iterations: 47
# Current loss value: 115189440.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_47_img.jpg
# Iterations 47 completed in 12s
# Start of iterations: 48
# Current loss value: 113564510.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_48_img.jpg
# Iterations 48 completed in 11s
# Start of iterations: 49
# Current loss value: 112091460.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_49_img.jpg
# Iterations 49 completed in 13s
# Start of iterations: 50
# Current loss value: 110656840.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_50_img.jpg
# Iterations 50 completed in 12s
# Start of iterations: 51
# Current loss value: 109317760.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_51_img.jpg
# Iterations 51 completed in 12s
# Start of iterations: 52
# Current loss value: 108288730.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_52_img.jpg
# Iterations 52 completed in 12s
# Start of iterations: 53
# Current loss value: 107217840.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_53_img.jpg
# Iterations 53 completed in 12s
# Start of iterations: 54
# Current loss value: 105882100.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_54_img.jpg
# Iterations 54 completed in 10s
# Start of iterations: 55
# Current loss value: 104703220.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_55_img.jpg
# Iterations 55 completed in 12s
# Start of iterations: 56
# Current loss value: 103575256.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_56_img.jpg
# Iterations 56 completed in 12s
# Start of iterations: 57
# Current loss value: 102338150.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_57_img.jpg
# Iterations 57 completed in 12s
# Start of iterations: 58
# Current loss value: 101394070.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_58_img.jpg
# Iterations 58 completed in 11s
# Start of iterations: 59
# Current loss value: 100431784.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_59_img.jpg
# Iterations 59 completed in 12s
# Start of iterations: 60
# Current loss value: 99608470.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_60_img.jpg
# Iterations 60 completed in 10s
# Start of iterations: 61
# Current loss value: 98527704.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_61_img.jpg
# Iterations 61 completed in 12s
# Start of iterations: 62
# Current loss value: 97690456.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_62_img.jpg
# Iterations 62 completed in 12s
# Start of iterations: 63
# Current loss value: 96854750.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_63_img.jpg
# Iterations 63 completed in 10s
# Start of iterations: 64
# Current loss value: 96095640.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_64_img.jpg
# Iterations 64 completed in 12s
# Start of iterations: 65
# Current loss value: 95140970.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_65_img.jpg
# Iterations 65 completed in 12s
# Start of iterations: 66
# Current loss value: 94370570.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_66_img.jpg
# Iterations 66 completed in 11s
# Start of iterations: 67
# Current loss value: 93573920.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_67_img.jpg
# Iterations 67 completed in 11s
# Start of iterations: 68
# Current loss value: 92893680.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_68_img.jpg
# Iterations 68 completed in 13s
# Start of iterations: 69
# Current loss value: 92210970.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_69_img.jpg
# Iterations 69 completed in 12s
# Start of iterations: 70
# Current loss value: 91336560.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_70_img.jpg
# Iterations 70 completed in 12s
# Start of iterations: 71
# Current loss value: 90513730.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_71_img.jpg
# Iterations 71 completed in 12s
# Start of iterations: 72
# Current loss value: 89860424.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_72_img.jpg
# Iterations 72 completed in 10s
# Start of iterations: 73
# Current loss value: 89192160.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_73_img.jpg
# Iterations 73 completed in 12s
# Start of iterations: 74
# Current loss value: 88598344.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_74_img.jpg
# Iterations 74 completed in 12s
# Start of iterations: 75
# Current loss value: 88005380.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_75_img.jpg
# Iterations 75 completed in 11s
# Start of iterations: 76
# Current loss value: 87401430.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_76_img.jpg
# Iterations 76 completed in 12s
# Start of iterations: 77
# Current loss value: 86746480.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_77_img.jpg
# Iterations 77 completed in 12s
# Start of iterations: 78
# Current loss value: 85948136.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_78_img.jpg
# Iterations 78 completed in 10s
# Start of iterations: 79
# Current loss value: 85219330.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_79_img.jpg
# Iterations 79 completed in 10s
# Start of iterations: 80
# Current loss value: 84667740.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_80_img.jpg
# Iterations 80 completed in 13s
# Start of iterations: 81
# Current loss value: 84064310.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_81_img.jpg
# Iterations 81 completed in 13s
# Start of iterations: 82
# Current loss value: 83542850.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_82_img.jpg
# Iterations 82 completed in 13s
# Start of iterations: 83
# Current loss value: 83025990.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_83_img.jpg
# Iterations 83 completed in 12s
# Start of iterations: 84
# Current loss value: 82549990.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_84_img.jpg
# Iterations 84 completed in 11s
# Start of iterations: 85
# Current loss value: 82020530.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_85_img.jpg
# Iterations 85 completed in 12s
# Start of iterations: 86
# Current loss value: 81517040.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_86_img.jpg
# Iterations 86 completed in 12s
# Start of iterations: 87
# Current loss value: 81023250.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_87_img.jpg
# Iterations 87 completed in 12s
# Start of iterations: 88
# Current loss value: 80582770.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_88_img.jpg
# Iterations 88 completed in 12s
# Start of iterations: 89
# Current loss value: 80039864.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_89_img.jpg
# Iterations 89 completed in 13s
# Start of iterations: 90
# Current loss value: 79566920.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_90_img.jpg
# Iterations 90 completed in 13s
# Start of iterations: 91
# Current loss value: 79095096.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_91_img.jpg
# Iterations 91 completed in 13s
# Start of iterations: 92
# Current loss value: 78613880.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_92_img.jpg
# Iterations 92 completed in 13s
# Start of iterations: 93
# Current loss value: 78100584.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_93_img.jpg
# Iterations 93 completed in 13s
# Start of iterations: 94
# Current loss value: 77525190.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_94_img.jpg
# Iterations 94 completed in 13s
# Start of iterations: 95
# Current loss value: 76978260.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_95_img.jpg
# Iterations 95 completed in 12s
# Start of iterations: 96
# Current loss value: 76456120.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_96_img.jpg
# Iterations 96 completed in 13s
# Start of iterations: 97
# Current loss value: 75904000.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_97_img.jpg
# Iterations 97 completed in 13s
# Start of iterations: 98
# Current loss value: 75525840.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_98_img.jpg
# Iterations 98 completed in 13s
# Start of iterations: 99
# Current loss value: 75084930.0
# Image saved as /home/oneran/testimages/my_results_at_iteration_99_img.jpg
# Iterations 99 completed in 13s
